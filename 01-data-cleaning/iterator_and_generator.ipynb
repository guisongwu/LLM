# %% [markdown]
# # iterator

# %%
lst = [1,2,3,4,5]
print(lst)
print(type(lst))

iter_lst = iter(lst)
for item in iter_lst:
    print(item)

print(type(iter_lst))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>
# 1
# 2
# 3
# 4
# 5
# <class 'list_iterator'>

# %% [markdown]
# # Generator

# %%
def countdown(n):
    i = n
    while i >=0:
        yield i
        i -= 1
        

iter_lst = countdown(3)
# print(next(iter_lst))
# print(next(iter_lst))


def fib(n):
    a, b = 0, 1
    for _ in range(n):
        yield a
        a, b = b, a+b


for i, item in enumerate(fib(5)):
    if i == 2:
        print(item)
# output: 0 1 1 2 3

a, b = 0, 1
    for _ in range(n):
        print(a)
        a, b = b, a+b
# Out:
# 1
